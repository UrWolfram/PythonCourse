# %% [markdown]
# ## How are in-demand skills trending for Data Analysts
#
# Methology
# 1. Aggregate skill counts monthly
# 2. Re-analyze based on percentage of total jobs
# 3. Plot the monthly skill demand

# %%
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

# Data Cleanup
df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])
df["job_skills"] = df["job_skills"].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# Filter for Data Analyst Jobs AND US Jobs
df_DA_US = df[(df["job_title_short"] == "Data Analyst") & (df["job_country"] == "United States")].copy()

# %%
df_DA_US["job_posted_month_no"] = df_DA_US["job_posted_date"].dt.month

# %%
df_DA_US_explode = df_DA_US.explode("job_skills")

df_DA_US_explode
# Out:
#        job_title_short                                    job_title  \
# 36        Data Analyst                                 Data Analyst
# 68        Data Analyst                    Sr. Research Data Analyst
# 68        Data Analyst                    Sr. Research Data Analyst
# 73        Data Analyst  Entry level / Systems Data Analyst (Remote)
# 73        Data Analyst  Entry level / Systems Data Analyst (Remote)
# ...                ...                                          ...
# 785685    Data Analyst                                 Data Analyst
# 785703    Data Analyst      Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
# 785705    Data Analyst    Expert Business Data Analyst - Now Hiring
#
#             job_location           job_via job_schedule_type  \
# 36        Des Moines, IA   via Trabajo.org         Full-time
# ...

# %%
df_DA_US_pivot = df_DA_US_explode.pivot_table(index="job_posted_month_no", columns="job_skills", aggfunc="size", fill_value=0)

df_DA_US_pivot.loc["total"] = df_DA_US_pivot.sum()

df_DA_US_pivot
# Out:
# job_skills           airflow  airtable  alteryx  angular  ansible  apl  arch  \
# job_posted_month_no
# 1                         39         7      206       21        7    1     0
# 2                         35         0      203       23        4    1     0
# 3                         39         1      219        5        5    6     1
# 4                         28         1      208        8        3    7     3
# 5                         27         3      144       15        8    9     1
# 6                         39         5      188        9        4    8     3
# 7                         42         2      160        5        3    5     5
# 8                         44         2      187        5        3   10     0
# 9                         22         3      145       11        2    3     4
# 10                        29         9      144       13        2    0     3
# 11                        23         1      126        4        2    0     1
# ...

# %%
df_DA_US_pivot = df_DA_US_pivot[df_DA_US_pivot.loc["total"].sort_values(ascending=False).index] # .loc[], da wir Reihe nach abgehen

df_DA_US_pivot = df_DA_US_pivot.drop("total")

df_DA_US_pivot_top_10 = df_DA_US_pivot.iloc[:, :10]

# %%
df_DA_US_pivot_top_10
# Out:
# job_skills            sql  excel  tableau  python   sas     r  power bi  word  \
# job_posted_month_no
# 1                    4601   3592     2488    2254  1832  1513      1337   968
# 2                    3168   2587     1676    1618  1212  1045      1122   738
# 3                    3226   2661     1804    1683  1238  1141      1054   736
# 4                    3220   2549     1789    1679  1302  1038      1057   695
# 5                    2581   2118     1432    1349   972   867       860   557
# 6                    2862   2382     1628    1609   984  1017       989   721
# 7                    2609   2118     1533    1438   996   881       881   587
# 8                    3414   2731     1951    2025  1276  1271      1208   752
# 9                    2295   1801     1353    1229   856   746       820   478
# 10                   2574   1922     1429    1373   960   835       921   498
# 11                   2054   1533     1148    1049   792   647       682   430
# ...

# %%
df_DA_US_pivot_top_10.plot(kind="line")
# Out:
# <Axes: xlabel='job_posted_month_no'>

# %% [markdown]
# now we have the count of every skill in every month. But we want the percentage.

# %%
DA_total = df_DA_US.groupby("job_posted_month_no").size()

DA_total
# Out:
# job_posted_month_no
# 1     8494
# 2     6124
# 3     6218
# 4     6049
# 5     4993
# 6     5683
# 7     5201
# 8     6634
# 9     4639
# 10    5271
# 11    4531
# 12    3979
# dtype: int64

# %% [markdown]
# now we have the count of all postings of every month. We want to devide it with the amount of skills mentioned in postings. We gonna use the pandas.DataFrame.div() Function.
# ![image.png](attachment:image.png)

# %%
df_DA_US_percent = df_DA_US_pivot.div(DA_total/100, axis=0) # axis = 0 means we divide though all rows

# %% [markdown]
# change month number to month name

# %%
df_DA_US_percent = df_DA_US_percent.reset_index()
df_DA_US_percent["job_posted_month"] = df_DA_US_percent[
    "job_posted_month_no"
].apply(lambda x: pd.to_datetime(x, format="%m").strftime("%b"))
df_DA_US_percent = df_DA_US_percent.set_index("job_posted_month")
df_DA_US_percent = df_DA_US_percent.drop(columns="job_posted_month_no")

df_DA_US_percent
# Out:
# job_skills              sql      excel    tableau     python        sas  \
# job_posted_month
# Jan               54.167648  42.288674  29.291264  26.536379  21.568166
# Feb               51.730895  42.243632  27.367734  26.420640  19.790986
# Mar               51.881634  42.795111  29.012544  27.066581  19.909939
# Apr               53.231939  42.139197  29.575136  27.756654  21.524219
# May               51.692369  42.419387  28.680152  27.017825  19.467254
# Jun               50.360725  41.914482  28.646841  28.312511  17.314799
# Jul               50.163430  40.722938  29.475101  27.648529  19.150163
# Aug               51.462165  41.166717  29.409105  30.524570  19.234248
# Sep               49.471869  38.823022  29.165768  26.492779  18.452253
# Oct               48.833238  36.463669  27.110605  26.048188  18.212863
# Nov               45.332156  33.833591  25.336570  23.151622  17.479585
# Dec               46.443830  38.326213  27.142498  27.041970  19.602915
#
# ...

# %%
df_DA_US_percent
# Out:
# job_skills              sql      excel    tableau     python        sas  \
# job_posted_month
# January           54.167648  42.288674  29.291264  26.536379  21.568166
# February          51.730895  42.243632  27.367734  26.420640  19.790986
# March             51.881634  42.795111  29.012544  27.066581  19.909939
# April             53.231939  42.139197  29.575136  27.756654  21.524219
# May               51.692369  42.419387  28.680152  27.017825  19.467254
# June              50.360725  41.914482  28.646841  28.312511  17.314799
# July              50.163430  40.722938  29.475101  27.648529  19.150163
# August            51.462165  41.166717  29.409105  30.524570  19.234248
# September         49.471869  38.823022  29.165768  26.492779  18.452253
# October           48.833238  36.463669  27.110605  26.048188  18.212863
# November          45.332156  33.833591  25.336570  23.151622  17.479585
# December          46.443830  38.326213  27.142498  27.041970  19.602915
#
# ...

# %%
df_plot = df_DA_US_percent.iloc[:, :5] # ":," alle Reihen ":5" die ersten fünf Werte
plt.figure(figsize=(8, 6))
sns.lineplot(data = df_plot, dashes="", palette="tab10")
sns.set_theme(style="ticks")
sns.despine()

plt.title("Trending Top Skills for Data Analysts in the US")
plt.ylabel("Liklihood in Job Posting")
plt.xlabel("2023")
plt.legend().remove()
plt.tight_layout()
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f"{int(y)}%"))


for i in range(5):
    if df_plot.columns[i] == "tableau":
            plt.text(11.2, (df_plot.iloc[-1, i] + 2), df_plot.columns[i])
            continue
    plt.text(11.2, df_plot.iloc[-1, i], df_plot.columns[i])
# Out:
# C:\Users\urovd\AppData\Local\Temp\ipykernel_11808\2173748513.py:3: UserWarning:
# The dashes list has fewer values (0) than needed (5) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data = df_plot, dashes="", palette="tab10")
